# %%
import importlib
import os
import gzip
import nibabel as nib
import nilearn.plotting as nplt

# %%
in_path = '/nese/mit/group/evlab/u/alexfung/parcellate/018/parcellation/main/parcellation.nii.gz'
# f = gzip.open(in_path)
parcellation = nib.load(in_path)
# data = f.read()

# %%
parcellation.affine
# Out:
# array([[  -2.,    0.,    0.,   90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])

# %%
arr = parcellation.get_fdata()
arr.shape
# Out:
# (91, 109, 91, 50)

# %%
arr.max()
# Out:
# 1.0

# %%
roi_idx = 0
data = arr[:,:,:,roi_idx]
ni_img = nib.Nifti1Image((data > 0).astype(float), affine=parcellation.affine)
nplt.plot_roi(roi_img=ni_img)
